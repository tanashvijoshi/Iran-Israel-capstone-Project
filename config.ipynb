# %%
# %sql
# CREATE STORAGE CREDENTIAL rod-databricks_credential
# WITH AZURE_SERVICE_PRINCIPAL (
#   CLIENT_ID = '<REMOVED_SECRET>',
#   CLIENT_SECRET = '<REMOVED_SECRET>',
#   TENANT_ID = '<REMOVED_SECRET>'
# );

#  since this is only available for premium we will use the storage key

# %%
spark.conf.set(
 <REMOVED_SECRET>
)

# %%
dbutils.fs.ls(<REMOVED_SECRET>)
